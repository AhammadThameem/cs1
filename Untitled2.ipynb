# %% [markdown]
# <a href="https://colab.research.google.com/github/AhammadThameem/cs1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = np.array(['jhon','bran','sam','peter',])
series = pd.Series(data,index=[10,11,12,13])
print(series)
# Out:
# 10     jhon
# 11     bran
# 12      sam
# 13    peter
# dtype: object

# %%
import pandas as pd

data = [['cs','1st'],
        ['at','2nd'],
        ['mec','3rd']]

df = pd.DataFrame(data,
columns=['department','year'],
index=[1,2,3])

print(df)
# Out:
#   department year
# 1         cs  1st
# 2         at  2nd
# 3        mec  3rd
